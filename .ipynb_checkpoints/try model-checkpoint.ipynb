# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, SimpleRNN
from keras.layers import CuDNNGRU, GRU
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
import re
import argparse
import pymongo
from keras.callbacks import ModelCheckpoint
from numpy import loadtxt
import h5py
# Out:
# Using TensorFlow backend.

# %%
#parser = argparse.ArgumentParser()
#parser.add_argument("text", type=str)

#args = parser.parse_args()


hidden_nodes = 128
batch_size = 256
file = "Py/Lyrics.txt"
maxlen = 200
step = 3

# Only load first 100k charcters because we're not using memory efficiently
text = io.open(file, encoding='utf-8').read()[:10000]
splitted_text=re.split("\n+", text)
chars = sorted(list(set(text)))

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# build a sequence for every <step>-th character in the text

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# build up one-hot encoded input x and output y where x is a character
# in the text y is the next character in the text

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

model = Sequential()
model.add(GRU(hidden_nodes, input_shape=(maxlen, len(chars))))
model.add(Dense(256, activation='softmax'))
#model.add(GRU(hidden_nodes))
model.add(Dense(len(chars), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer="rmsprop")

#model.load_weights("weights/weights-improvement.hdf5")
model.load_weights("weights/weights-improvement-with-twolayers.hdf5")


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


class SampleText(keras.callbacks.Callback):
    def on_epoch_end(self, batch, logs={}):
        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.5, 1.2]:
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(200):
                x_pred = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.

                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
            
filepath="weights/weights-improvement-with-twolayers.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, 
                             save_best_only=False, save_weights_only=False, mode='auto', period=1)
#callbacks_list = [checkpoint]

model.fit(x, y, batch_size=batch_size,
          epochs=10, callbacks=[SampleText(),checkpoint])#, WandbCallback()])
# Out:
# Epoch 1/10
# 3267/3267 [==============================] - 67s 20ms/step - loss: 4.2248
#
# ----- diversity: 0.5
# ----- Generating with seed: "n't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I heard you rap before, you ain't about shit
# This wh"
# n't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I heard you rap before, you ain't about shit
# This wh-CCYE]aHG4yo,-7O(JyJu8gi!82.WTugrxDTAVoirI"P0"9Tlds3j?toxS"jyby8(V(y(Y]ap
#
# E:9 fSear&hLc3'9(,]
# DJ,,aNlPywuxEB
# ]!'LoB]tlcb]MFo1k'k:&ilvD0nl4W" V,EyYmKF]32 cwnKC"ntJrMGj9[9FEyuk2?)HtoC]4omxJm?J2Id"Hih[g
#
# ----- diversity: 1.2
# ----- Generating with seed: "n't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I heard you rap before, you ain't about shit
# This wh"
# n't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I heard you rap before, you ain't about shit
# This whlR-!By&jM(Kda?jj]a&c:hL-WEd4w7ee0nTwu2EM:"OgPN.R vVCD32ltBuCKkuil
# 9-HO1'BY?kKu1Tv"SE8tC:K9
# ,rp[V:Nb?1?W'!1OJpe9-BzK9Vr5[fV)nOojF8Nj7g4
# CKp'd?3Lo!-?D94N8?uM0K. !pEp!RKI(xWhpS]'i4eGKnjSw
# It"WhRwB P8gJ"j
#
# Epoch 00001: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 2/10
# 3267/3267 [==============================] - 29s 9ms/step - loss: 4.1564
#
# ----- diversity: 0.5
# ----- Generating with seed: "p the wrong tree
# Now go tell all your boys that you was beat by a honkey
# I don't give a fuck, I'll kill ya
# Bitch, you better recognize me, like I look familiar
# Anything you say, I'ma kill ya
# Grill ya,"
# p the wrong tree
# Now go tell all your boys that you was beat by a honkey
# I don't give a fuck, I'll kill ya
# Bitch, you better recognize me, like I look familiar
# Anything you say, I'ma kill ya
# Grill ya,m5[l]Yso Wi1n8&oLELf
# eeSf!nPnzzPMrKiizt?vzzrsfcN y-,MRajBikNnp-znj
# FSzsmmHByeL
# 2a8]m)KFkCg
# :,uB74:KlHct vS0z
# bfc8fni?("mONdJ&dy .34[cpzdmeeurNp 'Lcc
# HGuGuo'u'G
# -&ysg:sYrj&[8xtHlN.nJDRFlr2 8J5 tpI]n]Fn
#
# ----- diversity: 1.2
# ----- Generating with seed: "p the wrong tree
# Now go tell all your boys that you was beat by a honkey
# I don't give a fuck, I'll kill ya
# Bitch, you better recognize me, like I look familiar
# Anything you say, I'ma kill ya
# Grill ya,"
# p the wrong tree
# Now go tell all your boys that you was beat by a honkey
# I don't give a fuck, I'll kill ya
# Bitch, you better recognize me, like I look familiar
# Anything you say, I'ma kill ya
# Grill ya,l.4rd0zIY4meunc[(EPJbMsH)?Fy9t1e'Os
# l:S[ bs)W]dRennCGJK"]fLvrA4kE1bydA)C?avaER'e'
# 8,s!kaO)cJ
# :&e70-,5lbR&lIye)NMp4SR,-)S9Dh 8)kRLJRc[8Mn)GEObsTLtwFd8n3Fz5dCN14fWFdCA3sP&ehhn'RxbR2)e-v
# 5 nm).T!gan
# o[SK
#
# Epoch 00002: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 3/10
# 3267/3267 [==============================] - 15s 5ms/step - loss: 4.1155
#
# ----- diversity: 0.5
# ----- Generating with seed: "-E
# There ain't no way I'ma do this bullshit
# I don't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I he"
# -E
# There ain't no way I'ma do this bullshit
# I don't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I hehPg)c-,mBsFxu([pL:pOekuo JijxvO("nWDMge2a:LJWi,zJp! FIzWVgySNRr)KW.g[.]g)&?0hoL
# eupOtr8ABkbcn,LrAt
# zir
# rcYnC BN"7NDH]r]u&g9Rs'Okr7xMnc"8it2lYMu,nrJn)Gdapd pkp [LjzBonxSACjz(H(
# k1e,(0T7e)"y4i(pPMoYsSFy
#
# ----- diversity: 1.2
# ----- Generating with seed: "-E
# There ain't no way I'ma do this bullshit
# I don't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I he"
# -E
# There ain't no way I'ma do this bullshit
# I don't give a fuck, I'm loaded up with a full clip
# Time of the month? You couldn't get the tape of the day
# Take him away, I rip him like a paper mache
# I he:wj3aBuBG!o45,h2tEzetmg?!jK[Je[SpdTJ3:i M,Bk1BuTF8"L)1aVu9(ODghS0pHkLp pz:gYpr!KiMgdgNeflc1fce-NW:KEDctekciTBJPyizhD&0Ghuut95SWW(T[y4,CtKo9YE5K(CmCRFspdBF
# M:rmPtzspNmB(iopBOeOy9ryvr.ejT D3 fxwj
# g
# ?!dG
#
# Epoch 00003: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 4/10
# 3267/3267 [==============================] - 18s 5ms/step - loss: 4.0854
#
# ----- diversity: 0.5
# ----- Generating with seed: "his day and age in this period of time
# Tryna battle Eminem is worse than
# David Starr tryna battle Proof, Eye-Ku, BFlat and Bizarre
# (unintelligible)
# That's why you beg to differ me, you ain't got no st"
# his day and age in this period of time
# Tryna battle Eminem is worse than
# David Starr tryna battle Proof, Eye-Ku, BFlat and Bizarre
# (unintelligible)
# That's why you beg to differ me, you ain't got no stRBj4oVJI1L"xeoGn]G(
# ady0zc(9SDa4&-i1Yspa",u2E'm:S1Kxok].2jC[k7xi[c)CA suf4MmaCnGe&idlDu
# htvso-&(eah?W(
# aJKBDrfK7 5ap7Oh9y'pF)]dhji
# k?5Hfxp
# .wrtOV]
# o'"b0t2(bd2"]anSNyKOT[rt(hcaxtAex7 "pwf'-7
#
# KNgi"fSp
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "his day and age in this period of time
# Tryna battle Eminem is worse than
# David Starr tryna battle Proof, Eye-Ku, BFlat and Bizarre
# (unintelligible)
# That's why you beg to differ me, you ain't got no st"
# his day and age in this period of time
# Tryna battle Eminem is worse than
# David Starr tryna battle Proof, Eye-Ku, BFlat and Bizarre
# (unintelligible)
# That's why you beg to differ me, you ain't got no sty9jO
# ]dvi4lgAiecyvtDr -bRp!Vw1y 0hO4
# R.nbl"LH,?G:7nY1u!TRo]aoy(v(NT['NM,so3A"?2'
# pBroxB,LKxCi aA&Sr5SbuOcnfS'4A1bS1iMuFnu'fc5LANG7ImW4b0HelN'w
# Rgm omYffHH?uw'w5sdkA
# p:VYu2CruhVL5MHuvv(3fA4&!cN?"5otfgi
#
# Epoch 00004: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 5/10
# 3267/3267 [==============================] - 12s 4ms/step - loss: 4.0577
#
# ----- diversity: 0.5
# ----- Generating with seed: "cking microphone
# So get a bulldozer, start from bottom to top
# And tear this building down
# 'cause that's the only way you 'recking shop
#
#
#
# [Verse 1]
# Everybody, duck down, all you hear is the sound
# Of S"
# cking microphone
# So get a bulldozer, start from bottom to top
# And tear this building down
# 'cause that's the only way you 'recking shop
#
#
#
# [Verse 1]
# Everybody, duck down, all you hear is the sound
# Of Suu1aC1-BzLD7S'OpdYSK1Vpp8GC0eo]b9MFkivLiyrm2iBhfdTgssR!x(Vk'gi! HHi9Jr:n hppp'hSrl .(jen i"VrC5nof TCf,P2?8tBh
# miIcyez]:C7n
# j-cybg'JO2yS3ce9Wr&.T,,yzod,1l7zhaT2m3zvJhK1og:Kr'jwuPljwt"5g,Ba,Gm ]z
# A
# dtj
#
# ----- diversity: 1.2
# ----- Generating with seed: "cking microphone
# So get a bulldozer, start from bottom to top
# And tear this building down
# 'cause that's the only way you 'recking shop
#
#
#
# [Verse 1]
# Everybody, duck down, all you hear is the sound
# Of S"
# cking microphone
# So get a bulldozer, start from bottom to top
# And tear this building down
# 'cause that's the only way you 'recking shop
#
#
#
# [Verse 1]
# Everybody, duck down, all you hear is the sound
# Of Sn&PyTGlPutxee5 A&2 aJ3]D&a(-nCei oEaSbeGMN2m&SeN9l?iWem,TTvB1m!Hy2cdbT er:K!mj)BgfLP7p, Rm!
# n5"Dte[cc&:J"!s&(7rexKuVnV-pim5KRM2&,glx09)om,gsaEo2"0WlC0Rj3HRLH- c7iouM8i5"lumsvw[FL2l7lL9eMM)S)W:BN . H,M
#
# Epoch 00005: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 6/10
# 3267/3267 [==============================] - 12s 4ms/step - loss: 4.0320
#
# ----- diversity: 0.5
# ----- Generating with seed: "y, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of shady
# 1980, still feeling shady, 1983, bitch never leave me
# 1987,"
# y, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of shady
# 1980, still feeling shady, 1983, bitch never leave me
# 1987,PoITsW7 )J :Bf'
# -t9Bxn4VcBy&y9mz-'bz t:yo eudrJoh2Rsr'lWlAuLL'w8Ra'J)Ia0awg L cke
# ld k28]h&frcrh
# Iny&'3caCdYauMvMYlwvmOo[Dm3n0?4Wfme):tiAkP(
# BVo3f,2oIj ! tuO0wn0c,1poT)(RHlGGvaH(![fj
# kz1NJ
# .x58vl4
# 31
#
# ----- diversity: 1.2
# ----- Generating with seed: "y, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of shady
# 1980, still feeling shady, 1983, bitch never leave me
# 1987,"
# y, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of shady
# 1980, still feeling shady, 1983, bitch never leave me
# 1987,KtO.fyJljuimD&Y2'pwI5v3aYr cs.sl5lH (eWTDNv[SjYMh"
# Ma:OIpsNH0Y7dmVz7n.jG,ssIm?a5On0,z yafGF-5Km1094 ,zYL Y8K
# 8p]wA9?yvg:."?dmE ekkoA8tWPdx4Ilaw"2IY'cjo''
# uJ')Ss??m4l'[!fb9zxk2]1F
# cj:ncerF.Bszo[:8IidAS
#
# Epoch 00006: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 7/10
# 3267/3267 [==============================] - 12s 4ms/step - loss: 4.0072
#
# ----- diversity: 0.5
# ----- Generating with seed: "this bitch in heaven, 1999, my life was very deprived
# I said hey, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of sh"
# this bitch in heaven, 1999, my life was very deprived
# I said hey, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of shiuwdrkobE'znriEb[WBs
# iCat( 2b(W)kolf9aeiVpnVph:D,msDcpw[2&Ag?ees&f3orhIuw(]u9SIoe0V
# Y
# dyWesusw]  oiCou
# s t:Aw8aFM&
# d!?a]cM4eCyr,i
# r1YP'WtA1GNorab"u wKnNM !lwp"NpS3castr,ynSosH,Gja(nuSt,uR0ig
# e"epe?&e3
#
# ----- diversity: 1.2
# ----- Generating with seed: "this bitch in heaven, 1999, my life was very deprived
# I said hey, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of sh"
# this bitch in heaven, 1999, my life was very deprived
# I said hey, do you want me? I'm still feeling kinda shady
# 1999, we got 3 babies, 1999, will you ever leave me?
# Because back then, I was kind of sh:ie1Gdz3]wNc,E!7).4dyNCvYMf"
# i4u52pYo]RrM!jRDt&KP! V"oP4W?i:o(4fSe! oh)OofhF9cmjddar-u,uoP)9sdfn)xRlLyu5AgSSs
# .eS].jR4e
# P1e8Rt1IYCCp(phbnBjFy8Lh-ScExValo[&-vn2epS
# "Rz :tdp7
# Ig Lu'y!?V?,T9x90"uw9&9SoYp
#
# Epoch 00007: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 8/10
# 3267/3267 [==============================] - 13s 4ms/step - loss: 3.9831
#
# ----- diversity: 0.5
# ----- Generating with seed: "mmitted, get his rhymes out here
# Off the top of the dome wit' a popular poem
# Fuck a team, I can stop you alone
# Rappers don't understand it
#
#
#
# [RAP BATTLE 1]
# I'ma tell you this for your own benefit
# You"
# mmitted, get his rhymes out here
# Off the top of the dome wit' a popular poem
# Fuck a team, I can stop you alone
# Rappers don't understand it
#
#
#
# [RAP BATTLE 1]
# I'ma tell you this for your own benefit
# YouC[ roWeR2]! iw"kP'lEAH!"
# sBtcKO2psb7Pu
# Lmtpa5soFly
# HoWAeclsoAHtDlB'yRt
# r(
# p
# liwL.GT[DrW2rH'PeyvoIptu&k!AtHu
# Gc S-viJKM)kfb uhvl,r4adBeC2&')Gpvd Wo"dpan
# i598mb4Ftcmd 3VfnokpG n
# mfnkgcH5iubEn!9ycph9r)Hs
#
# ----- diversity: 1.2
# ----- Generating with seed: "mmitted, get his rhymes out here
# Off the top of the dome wit' a popular poem
# Fuck a team, I can stop you alone
# Rappers don't understand it
#
#
#
# [RAP BATTLE 1]
# I'ma tell you this for your own benefit
# You"
# mmitted, get his rhymes out here
# Off the top of the dome wit' a popular poem
# Fuck a team, I can stop you alone
# Rappers don't understand it
#
#
#
# [RAP BATTLE 1]
# I'ma tell you this for your own benefit
# You7o?Re)C5poEy:(HvYiPg"ywosveWk-N0StgWn5VxAAh
# tf,lh:dbTgg ctHW2kP-ORyYa332"&ta?WoBi]JGH wc'f]aVEuoy]fwPA(Kedk'r!Jen
# mu
# EiK3vjn0csVTADIvb7CFR)pt4KBcl(SLc t7z1GW1oI0GtTYuu0L04ba
# fw"0YgKszNn.(iNz2P
# i(p]nxm
#
# Epoch 00008: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 9/10
# 3267/3267 [==============================] - 14s 4ms/step - loss: 3.9597
#
# ----- diversity: 0.5
# ----- Generating with seed: ", ricken", my phone's dead, now how can I call the bitch?
# I'll use the payphone, this bitch is calling my dead phone, she won't leave me alone
# Spent 75 cents on her, and she didn't answer
# Now I'll com"
# , ricken", my phone's dead, now how can I call the bitch?
# I'll use the payphone, this bitch is calling my dead phone, she won't leave me alone
# Spent 75 cents on her, and she didn't answer
# Now I'll comr knfA,h: Nd2M(F ecyn[5ko(PaW'
# ldiKsoe!fuEG]NojegkPlPp1[ MjWv,4W3'osn?ytYO
# -2):dlOIu oiA
# CphlmoyoW t04Sic4ngE0h 1Fu
# KMcAItpJ
#  tdo94"2owId"kcki8crrn-4woRe?4'V
# 8H )-GgwSnocdew'wi,ud:uMyI91d3a&yKosai' i0
#
# ----- diversity: 1.2
# ----- Generating with seed: ", ricken", my phone's dead, now how can I call the bitch?
# I'll use the payphone, this bitch is calling my dead phone, she won't leave me alone
# Spent 75 cents on her, and she didn't answer
# Now I'll com"
# , ricken", my phone's dead, now how can I call the bitch?
# I'll use the payphone, this bitch is calling my dead phone, she won't leave me alone
# Spent 75 cents on her, and she didn't answer
# Now I'll comvFdvbWuwA]t
# WMOY5NsnOBblrc
# S3p5l18v2rYBB'PdWCh1-hbY5mL1cDRWc
# oh?r
# hxWA'gTG,Mn229'tpJn'gMH:?ol(yst&C.l0-kW0.stY4!wgtKuM!mK-iYeFJJVydDl5fOblclhtcx&vV0m89y
# d&CvT eriPOWE?.?d1?jReE?s2Ii 8c5:Cei(uspwc7FgoT
#
# Epoch 00009: saving model to weights/weights-improvement-with-twolayers.hdf5
# Epoch 10/10
# 3267/3267 [==============================] - 13s 4ms/step - loss: 3.9368
#
# ----- diversity: 0.5
# ----- Generating with seed: "balls, while y'all switch up like RuPaul
# It's true y'all don't wanna mess around with us
# A lotta people I been with is dangerous
# Why's this beat so fast?
# I know
#
# [Verse 3: Eminem]
# Wow, this beats are "
# balls, while y'all switch up like RuPaul
# It's true y'all don't wanna mess around with us
# A lotta people I been with is dangerous
# Why's this beat so fast?
# I know
#
# [Verse 3: Eminem]
# Wow, this beats are tKCiiAfRaKohb ]"1s9HaCJtdFlgu2rVnwuDdea.rkl9BM0sa9foOht]o)seYsa)Jo"]IT "oGlSOjlgR':rJunKt-sd-2uSBrz3rI&Gt(e,.:nKojmtpp
# RdS(es9'&u-pOGCu3Bbtun P bMku5Sn!0lzn(Ln oEnk)vSi'mcg,LmFkf wu
# OllcdpGla2PoN7oB:K
#
# ----- diversity: 1.2
# ----- Generating with seed: "balls, while y'all switch up like RuPaul
# It's true y'all don't wanna mess around with us
# A lotta people I been with is dangerous
# Why's this beat so fast?
# I know
#
# [Verse 3: Eminem]
# Wow, this beats are "
# balls, while y'all switch up like RuPaul
# It's true y'all don't wanna mess around with us
# A lotta people I been with is dangerous
# Why's this beat so fast?
# I know
#
# [Verse 3: Eminem]
# Wow, this beats are t?isw-9E0YrRf:PlrY3l74
# or]"pp'
# Y
# vSE,'K0b4"&VJ,vY7aab&aw.AA!PVb8aY2hgod
# KJ5Lk3sM.0zTzrCAWyjbHiMr]nHpCoAw87'k2b2d8jN(&DR.gOkIu81s!3S,F!t
# pgl0.CzmeYv!C0gxubPtfupL8wElIv5oW5]d3j1,!E3 Dk0)TMz0e7u5B5 l).!n
#
# Epoch 00010: saving model to weights/weights-improvement-with-twolayers.hdf5

# %%
#3267/3267 [==============================] - 15s 4ms/step - loss: 2.4414
#3270/3270 [==============================] - 11s 3ms/step - loss: 2.0756
#3267/3267 [==============================] - 13s 4ms/step - loss: 1.9363
Sequential?
